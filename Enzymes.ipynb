# %%
import pandas as pd


train_df1 = pd.read_csv("C:/Users/pfali/Downloads/playground-series-s3e18/train.csv")
test_df1 = pd.read_csv("C:/Users/pfali/Downloads/playground-series-s3e18/test.csv")

train_df=train_df1.copy()
test_df=train_df1.copy()

# %% [markdown]
# Targets are EC1 or EC2, so we can delete other enzyme types.

# %%
train_df.drop(columns=['EC3', 'EC4', 'EC5','EC6'],axis=1,inplace=True)

# %%
pd.set_option('display.max_columns', None)
train_df.head()
# Out:
#    id     BertzCT       Chi1     Chi1n      Chi1v     Chi2n      Chi2v  \
# 0   0  323.390782   9.879918  5.875576   5.875576  4.304757   4.304757
# 1   1  273.723798   7.259037  4.441467   5.834958  3.285046   4.485235
# 2   2  521.643822  10.911303  8.527859  11.050864  6.665291   9.519706
# 3   3  567.431166  12.453343  7.089119  12.833709  6.478023  10.978151
# 4   4  112.770735   4.414719  2.866236   2.866236  1.875634   1.875634
#
#       Chi3v     Chi4n  EState_VSA1  EState_VSA2  ExactMolWt  FpDensityMorgan1  \
# 0  2.754513  1.749203     0.000000    11.938294  222.068080          1.181818
# 1  2.201375  1.289775    45.135471     0.000000  260.029719          1.346154
# 2  5.824822  1.770579    15.645394     6.606882  382.131027          1.085714
# 3  7.914542  3.067181    95.639554     0.000000  530.070277          1.162791
# 4  1.036450  0.727664    17.980451    12.841643  118.062994          1.444444
#
# ...

# %%
pd.set_option('display.max_columns', None)
test_df.head()
# Out:
#    id     BertzCT       Chi1     Chi1n      Chi1v     Chi2n      Chi2v  \
# 0   0  323.390782   9.879918  5.875576   5.875576  4.304757   4.304757
# 1   1  273.723798   7.259037  4.441467   5.834958  3.285046   4.485235
# 2   2  521.643822  10.911303  8.527859  11.050864  6.665291   9.519706
# 3   3  567.431166  12.453343  7.089119  12.833709  6.478023  10.978151
# 4   4  112.770735   4.414719  2.866236   2.866236  1.875634   1.875634
#
#       Chi3v     Chi4n  EState_VSA1  EState_VSA2  ExactMolWt  FpDensityMorgan1  \
# 0  2.754513  1.749203     0.000000    11.938294  222.068080          1.181818
# 1  2.201375  1.289775    45.135471     0.000000  260.029719          1.346154
# 2  5.824822  1.770579    15.645394     6.606882  382.131027          1.085714
# 3  7.914542  3.067181    95.639554     0.000000  530.070277          1.162791
# 4  1.036450  0.727664    17.980451    12.841643  118.062994          1.444444
#
# ...

# %%
pd.set_option('display.max_columns', None)
train_df.describe(include="all")
# Out:
#                  id       BertzCT          Chi1         Chi1n         Chi1v  \
# count  14838.000000  14838.000000  14838.000000  14838.000000  14838.000000
# mean    7418.500000    515.153604      9.135189      5.854307      6.738497
# std     4283.505982    542.456370      6.819989      4.647064      5.866444
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%     3709.250000    149.103601      4.680739      2.844556      2.932842
# 50%     7418.500000    290.987941      6.485270      4.052701      4.392859
# 75%    11127.750000    652.652585     11.170477      7.486791      8.527859
# max    14837.000000   4069.959780     69.551167     50.174588     53.431954
#
#               Chi2n         Chi2v         Chi3v         Chi4n   EState_VSA1  \
# count  14838.000000  14838.000000  14838.000000  14838.000000  14838.000000
# mean       4.432570      5.253221      3.418749      1.773472     29.202823
# ...

# %%
pd.set_option('display.max_rows', None)
train_df.isnull().sum()
# Out:
# id                   0
# BertzCT              0
# Chi1                 0
# Chi1n                0
# Chi1v                0
# Chi2n                0
# Chi2v                0
# Chi3v                0
# Chi4n                0
# EState_VSA1          0
# EState_VSA2          0
# ExactMolWt           0
# FpDensityMorgan1     0
# FpDensityMorgan2     0
# FpDensityMorgan3     0
# HallKierAlpha        0
# HeavyAtomMolWt       0
# Kappa3               0
# MaxAbsEStateIndex    0
# MinEStateIndex       0
# NumHeteroatoms       0
# PEOE_VSA10           0
# PEOE_VSA14           0
# PEOE_VSA6            0
# PEOE_VSA7            0
# PEOE_VSA8            0
# SMR_VSA10            0
# SMR_VSA5             0
# SlogP_VSA3           0
# VSA_EState9          0
# fr_COO               0
# fr_COO2              0
# EC1                  0
# EC2                  0
# dtype: int64

# %%
pd.set_option('display.max_columns', None)
train_df.dtypes
# Out:
# id                     int64
# BertzCT              float64
# Chi1                 float64
# Chi1n                float64
# Chi1v                float64
# Chi2n                float64
# Chi2v                float64
# Chi3v                float64
# Chi4n                float64
# EState_VSA1          float64
# EState_VSA2          float64
# ExactMolWt           float64
# FpDensityMorgan1     float64
# FpDensityMorgan2     float64
# FpDensityMorgan3     float64
# HallKierAlpha        float64
# HeavyAtomMolWt       float64
# Kappa3               float64
# MaxAbsEStateIndex    float64
# MinEStateIndex       float64
# NumHeteroatoms         int64
# PEOE_VSA10           float64
# PEOE_VSA14           float64
# PEOE_VSA6            float64
# PEOE_VSA7            float64
# PEOE_VSA8            float64
# SMR_VSA10            float64
# SMR_VSA5             float64
# SlogP_VSA3           float64
# VSA_EState9          float64
# fr_COO                 int64
# fr_COO2                int64
# ...

# %% [markdown]
# There is nothing to impute. All features are numerical, some of them might need rescaling.

# %%
corr_matrix = train_df.corr()
corr_matrix["EC1"].sort_values(ascending=False)
# Out:
# EC1                  1.000000
# MinEStateIndex       0.208827
# PEOE_VSA6            0.084942
# PEOE_VSA7            0.083718
# PEOE_VSA8            0.052619
# EState_VSA2          0.040751
# fr_COO2              0.014989
# fr_COO               0.014353
# id                   0.010901
# Kappa3               0.002552
# FpDensityMorgan1     0.000125
# FpDensityMorgan2    -0.002198
# FpDensityMorgan3    -0.005985
# HallKierAlpha       -0.020765
# SMR_VSA10           -0.025373
# Chi4n               -0.054333
# Chi1n               -0.055030
# Chi2n               -0.056264
# SMR_VSA5            -0.056336
# BertzCT             -0.060120
# Chi3v               -0.061797
# Chi2v               -0.064649
# Chi1v               -0.065679
# Chi1                -0.069660
# ExactMolWt          -0.075954
# HeavyAtomMolWt      -0.078682
# VSA_EState9         -0.093636
# SlogP_VSA3          -0.109439
# PEOE_VSA10          -0.115469
# MaxAbsEStateIndex   -0.122893
# PEOE_VSA14          -0.123488
# ...

# %%
corr_matrix = train_df.corr()
corr_matrix["EC2"].sort_values(ascending=False)
# Out:
# EC2                  1.000000
# HallKierAlpha        0.039798
# PEOE_VSA14           0.017258
# Kappa3               0.002803
# MinEStateIndex       0.000630
# FpDensityMorgan1    -0.003914
# FpDensityMorgan2    -0.004619
# FpDensityMorgan3    -0.004831
# id                  -0.005180
# PEOE_VSA10          -0.010913
# EState_VSA1         -0.012578
# NumHeteroatoms      -0.016646
# BertzCT             -0.024188
# Chi2n               -0.027566
# Chi1                -0.027768
# Chi2v               -0.028716
# Chi3v               -0.029776
# HeavyAtomMolWt      -0.029901
# Chi1v               -0.029933
# Chi4n               -0.030007
# Chi1n               -0.030101
# ExactMolWt          -0.030487
# PEOE_VSA7           -0.030671
# SlogP_VSA3          -0.031082
# MaxAbsEStateIndex   -0.031225
# SMR_VSA5            -0.031442
# VSA_EState9         -0.034380
# EState_VSA2         -0.034391
# PEOE_VSA6           -0.040313
# SMR_VSA10           -0.041555
# PEOE_VSA8           -0.044334
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

features = ["BertzCT","Chi1","Chi1n","Chi1v","Chi2n","Chi2v","Chi3v","Chi4n","EState_VSA1","EState_VSA2","ExactMolWt","FpDensityMorgan1","FpDensityMorgan2","FpDensityMorgan3","HallKierAlpha","HeavyAtomMolWt","Kappa3","MaxAbsEStateIndex","MinEStateIndex","NumHeteroatoms","PEOE_VSA10","PEOE_VSA14","PEOE_VSA6","PEOE_VSA7","PEOE_VSA8","SMR_VSA10","SMR_VSA5","SlogP_VSA3","VSA_EState9","fr_COO","fr_COO2"]

for feature in features:
    sns.relplot(data=train_df, x="EC1", y=feature)
    plt.show
# Out:
# C:\Users\pfali\Desktop\Pyton\Venv\Lib\Kaggle\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\pfali\Desktop\Pyton\Venv\Lib\Kaggle\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\pfali\Desktop\Pyton\Venv\Lib\Kaggle\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\pfali\Desktop\Pyton\Venv\Lib\Kaggle\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\pfali\Desktop\Pyton\Venv\Lib\Kaggle\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# ...

# %%
features = ["BertzCT","Chi1","Chi1n","Chi1v","Chi2n","Chi2v","Chi3v","Chi4n","EState_VSA1","EState_VSA2","ExactMolWt","FpDensityMorgan1","FpDensityMorgan2","FpDensityMorgan3","HallKierAlpha","HeavyAtomMolWt","Kappa3","MaxAbsEStateIndex","MinEStateIndex","NumHeteroatoms","PEOE_VSA10","PEOE_VSA14","PEOE_VSA6","PEOE_VSA7","PEOE_VSA8","SMR_VSA10","SMR_VSA5","SlogP_VSA3","VSA_EState9","fr_COO","fr_COO2"]

for feature in features:
    sns.relplot(data=train_df, x="EC2", y=feature)
    plt.show
# Out:
# C:\Users\pfali\Desktop\Pyton\Venv\Lib\Kaggle\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\pfali\Desktop\Pyton\Venv\Lib\Kaggle\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\pfali\Desktop\Pyton\Venv\Lib\Kaggle\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\pfali\Desktop\Pyton\Venv\Lib\Kaggle\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\pfali\Desktop\Pyton\Venv\Lib\Kaggle\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# ...

# %% [markdown]
# Taking into account the above plots, some outliers will be removed:
# BertzCT – over 3000
# Chi1 – over 60
# Chi1n – over 50
# Chi1v – as above
# Chi2n – over 30
# Chi2v – between 34 and 35
# Estate_VSA1 – over 350
# ExactMolWt – over 2000
# HeavyAtomMolWt – over 2000
# PEOE-VSA6 – over 300
# PEOE-VSA7 – over 200
# SMR_VSA5 – over 400
# VSA_Estate9 – over 350
# Chi1 – over 60
# Chi1n – between 45 and 50
# Chi1v – over 50
# Chi2n – over 30
# EState_VSA1 – over 350
# ExactMolWT – over 2000
# HeavyAtomMolt – over 2000
# PEOE_VSA6 – over 250
# PEOE_VSA7 – over 200
# SMR_VSA5 – around 500
# VSA_Estate9 – over 350
#
# Only the most noticeable outliers were chosen, because the dataset is relatively small.

# %%
train_df_EC1=train_df.copy()
train_df_EC2=train_df1.copy()

train_df_EC1.drop(['id','EC2',],axis=1,inplace=True)

import lazypredict
from lazypredict.Supervised import LazyClassifier

from sklearn.model_selection import train_test_split

X = train_df_EC1.drop(["EC1"],axis=1)
y = train_df_EC1["EC1"]

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.25,random_state =123)

clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
prediction = clf.fit(X_train, X_test, y_train, y_test)
print(prediction)
# Out:
#  97%|███████████████████████████████████████████████████████████████████████████████▏  | 28/29 [01:01<00:02,  2.13s/it]
# [LightGBM] [Info] Number of positive: 7421, number of negative: 3707
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002323 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6299
# [LightGBM] [Info] Number of data points in the train set: 11128, number of used features: 31
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666876 -> initscore=0.694091
# [LightGBM] [Info] Start training from score 0.694091
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [01:01<00:00,  2.12s/it]
# (                               Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# RandomForestClassifier             0.70               0.62     0.62      0.68
# ...

# %%
filter = train_df[train_df['BertzCT']>3000].index
train_df.drop(filter, inplace=True)

# %%
filter2=train_df[train_df['Chi1']>60].index
train_df.drop(filter2, inplace=True)

# %%
#filter3=train_df[train_df['Chi1n']>45].index
#train_df.drop(filter2, inplace=True)

# %%
filter4=train_df[train_df['Chi1v']>45].index
train_df.drop(filter4, inplace=True)

# %%
filter5=train_df[train_df['Chi2n']>30].index
train_df.drop(filter5, inplace=True)

# %%
filter6=train_df[train_df['Chi2v']>34].index
train_df.drop(filter6, inplace=True)

# %%
filter7=train_df[train_df['EState_VSA1']>350].index
train_df.drop(filter7, inplace=True)

# %%
filter8=train_df[train_df['ExactMolWt']>2000].index
train_df.drop(filter8, inplace=True)

# %%
filter9=train_df[train_df['HeavyAtomMolWt']>2000].index
train_df.drop(filter9, inplace=True)

# %%
filter10=train_df[train_df['PEOE_VSA6']>300].index
train_df.drop(filter10, inplace=True)

# %%
filter11=train_df[train_df['PEOE_VSA7']>200].index
train_df.drop(filter11, inplace=True)

# %%
filter12=train_df[train_df['PEOE_VSA7']>200].index
train_df.drop(filter12, inplace=True)

# %%
filter13=train_df[train_df['SMR_VSA5']>400].index
train_df.drop(filter13, inplace=True)

# %%
filter14=train_df[train_df['VSA_EState9']>350].index
train_df.drop(filter14, inplace=True)

# %%
corr_matrix = train_df.corr()
corr_matrix["EC1"].sort_values(ascending=False)
# Out:
# EC1                  1.000000
# MinEStateIndex       0.208521
# PEOE_VSA6            0.090090
# PEOE_VSA7            0.088149
# PEOE_VSA8            0.052795
# EState_VSA2          0.042707
# fr_COO2              0.014957
# fr_COO               0.014318
# id                   0.010963
# Kappa3               0.002895
# FpDensityMorgan1     0.000062
# FpDensityMorgan2    -0.002285
# FpDensityMorgan3    -0.006061
# HallKierAlpha       -0.023034
# SMR_VSA10           -0.024077
# Chi4n               -0.051670
# Chi1n               -0.052584
# Chi2n               -0.054083
# SMR_VSA5            -0.055692
# BertzCT             -0.058806
# Chi3v               -0.059818
# Chi2v               -0.062802
# Chi1v               -0.063548
# Chi1                -0.067296
# ExactMolWt          -0.074123
# HeavyAtomMolWt      -0.076881
# VSA_EState9         -0.092619
# SlogP_VSA3          -0.108838
# PEOE_VSA10          -0.114320
# MaxAbsEStateIndex   -0.122029
# PEOE_VSA14          -0.122894
# ...

# %%
corr_matrix = train_df.corr()
corr_matrix["EC2"].sort_values(ascending=False)
# Out:
# EC2                  1.000000
# HallKierAlpha        0.040475
# PEOE_VSA14           0.018828
# Kappa3               0.002702
# MinEStateIndex       0.000340
# FpDensityMorgan1    -0.003909
# FpDensityMorgan2    -0.004613
# id                  -0.004614
# FpDensityMorgan3    -0.004819
# PEOE_VSA10          -0.011099
# EState_VSA1         -0.013602
# NumHeteroatoms      -0.016700
# BertzCT             -0.024056
# PEOE_VSA7           -0.027919
# Chi2n               -0.028096
# Chi1                -0.028188
# Chi2v               -0.029198
# Chi3v               -0.030120
# HeavyAtomMolWt      -0.030176
# Chi4n               -0.030230
# Chi1v               -0.030309
# Chi1n               -0.030488
# SMR_VSA5            -0.030604
# ExactMolWt          -0.030867
# MaxAbsEStateIndex   -0.030978
# SlogP_VSA3          -0.031549
# EState_VSA2         -0.034661
# VSA_EState9         -0.035956
# SMR_VSA10           -0.041878
# PEOE_VSA6           -0.042976
# PEOE_VSA8           -0.045270
# ...

# %% [markdown]
# The deletion of outliers slightly changed the correlation matrices. Let's make a copy of the traindataset for each target value and check how currently each model performs.

# %%
train_df_EC1=train_df.copy()
train_df_EC2=train_df1.copy()

train_df_EC1.drop(['id','EC2',],axis=1,inplace=True)

import lazypredict
from lazypredict.Supervised import LazyClassifier

from sklearn.model_selection import train_test_split

X = train_df_EC1.drop(["EC1"],axis=1)
y = train_df_EC1["EC1"]

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.25,random_state =123)

clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
prediction = clf.fit(X_train, X_test, y_train, y_test)
print(prediction)
# Out:
#  97%|███████████████████████████████████████████████████████████████████████████████▏  | 28/29 [01:23<00:02,  2.79s/it]
# [LightGBM] [Info] Number of positive: 7456, number of negative: 3653
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006224 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6277
# [LightGBM] [Info] Number of data points in the train set: 11109, number of used features: 31
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.671168 -> initscore=0.713470
# [LightGBM] [Info] Start training from score 0.713470
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [01:24<00:00,  2.90s/it]
# (                               Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.70               0.62     0.62      0.68
# ...

# %%
train_df_EC2.drop(['id','EC1',],axis=1,inplace=True)

X2 = train_df_EC2.drop(["EC2"],axis=1)
y2 = train_df_EC2["EC2"]

X_train2, X_test2, y_train2, y_test2 = train_test_split(X, y,test_size=.25,random_state =123)

clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
prediction = clf.fit(X_train2, X_test2, y_train2, y_test2)
print(prediction)
# Out:
#  97%|███████████████████████████████████████████████████████████████████████████████▏  | 28/29 [01:20<00:02,  2.85s/it]
# [LightGBM] [Info] Number of positive: 7456, number of negative: 3653
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004135 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6277
# [LightGBM] [Info] Number of data points in the train set: 11109, number of used features: 31
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.671168 -> initscore=0.713470
# [LightGBM] [Info] Start training from score 0.713470
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [01:21<00:00,  2.80s/it]
# (                               Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.70               0.62     0.62      0.68
# ...

# %% [markdown]
# These are not the greatest results, so let's try to remove the features that seem the least correlated with the target.

# %%
train_df_EC1.drop(['FpDensityMorgan1','FpDensityMorgan2','FpDensityMorgan3','Kappa3',],axis=1,inplace=True)

X = train_df_EC1.drop(["EC1"],axis=1)
y = train_df_EC1["EC1"]

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.25,random_state =123)

clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
prediction = clf.fit(X_train, X_test, y_train, y_test)
print(prediction)
# Out:
#  97%|███████████████████████████████████████████████████████████████████████████████▏  | 28/29 [01:24<00:03,  3.00s/it]
# [LightGBM] [Info] Number of positive: 7456, number of negative: 3653
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003206 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5377
# [LightGBM] [Info] Number of data points in the train set: 11109, number of used features: 27
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.671168 -> initscore=0.713470
# [LightGBM] [Info] Start training from score 0.713470
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [01:24<00:00,  2.92s/it]
# (                               Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# GaussianNB                         0.68               0.64     0.64      0.68
# ...

# %%
correlated = train_df_EC1.drop(["EC1"],axis=1)
correlated.corr()
# Out:
#                    BertzCT  Chi1  Chi1n  Chi1v  Chi2n  Chi2v  Chi3v  Chi4n  \
# BertzCT               1.00  0.94   0.91   0.93   0.90   0.93   0.92   0.82
# Chi1                  0.94  1.00   0.97   0.98   0.96   0.97   0.96   0.88
# Chi1n                 0.91  0.97   1.00   0.98   0.98   0.97   0.97   0.91
# Chi1v                 0.93  0.98   0.98   1.00   0.96   0.99   0.97   0.88
# Chi2n                 0.90  0.96   0.98   0.96   1.00   0.97   0.97   0.93
# Chi2v                 0.93  0.97   0.97   0.99   0.97   1.00   0.98   0.89
# Chi3v                 0.92  0.96   0.97   0.97   0.97   0.98   1.00   0.93
# Chi4n                 0.82  0.88   0.91   0.88   0.93   0.89   0.93   1.00
# EState_VSA1           0.73  0.75   0.70   0.74   0.68   0.74   0.72   0.59
# EState_VSA2           0.67  0.67   0.66   0.67   0.65   0.67   0.66   0.58
# ExactMolWt            0.92  0.96   0.94   0.96   0.93   0.96   0.94   0.84
# ...

# %% [markdown]
# We are checking correlations between the features. Most of them are highly correlated with each other, which means they carry similar information and thus, some of them should (one for a pair), should be excluded. We will exclude: BertzCT, Chi1, HeavyAtomMolWt, ExactMolWt, Chi1v, Ch1n, Chi2v, Chi3v, VSA_EState9, Chi2n, SlogP_VSA3, NumHeteroatoms, Chi4n, PEOE_VSA8, SMR_VSA10 and then check the correlations again.

# %%
#train_df_EC1.drop(["BertzCT","Chi1","HeavyAtomMolWt","ExactMolWt","Chi1v","Chi1n","Chi2v","Chi3v","Chi2n","VSA_EState9","SlogP_VSA3","NumHeteroatoms","Chi4n","PEOE_VSA8","SMR_VSA10"],axis=1,inplace=True)
train_df_EC1.drop(["Chi4n","PEOE_VSA8","SMR_VSA10"],axis=1,inplace=True)
correlated2 = train_df_EC1.drop(["EC1"],axis=1)
correlated2.corr()
# Out:
#                    EState_VSA1  EState_VSA2  HallKierAlpha  MaxAbsEStateIndex  \
# EState_VSA1               1.00         0.38          -0.38               0.58
# EState_VSA2               0.38         1.00          -0.58               0.45
# HallKierAlpha            -0.38        -0.58           1.00              -0.46
# MaxAbsEStateIndex         0.58         0.45          -0.46               1.00
# MinEStateIndex           -0.76        -0.32           0.21              -0.56
# PEOE_VSA10                0.73         0.41          -0.37               0.48
# PEOE_VSA14                0.33         0.08          -0.04               0.25
# PEOE_VSA6                 0.15         0.41          -0.34               0.20
# PEOE_VSA7                -0.16         0.17          -0.24               0.08
# SMR_VSA5                  0.58         0.45          -0.37               0.50
# fr_COO                   -0.10        -0.10          -0.10              -0.01
# ...

# %%
X = train_df_EC1.drop(["EC1"],axis=1)
y = train_df_EC1["EC1"]

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.25,random_state =123)

clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
prediction = clf.fit(X_train, X_test, y_train, y_test)
print(prediction)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [00:44<00:00,  1.52s/it]
# [LightGBM] [Info] Number of positive: 7456, number of negative: 3653
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000216 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2056
# [LightGBM] [Info] Number of data points in the train set: 11109, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.671168 -> initscore=0.713470
# [LightGBM] [Info] Start training from score 0.713470
# (                               Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# QuadraticDiscriminantAnalysis      0.68               0.64     0.64      0.68
# NearestCentroid                    0.65               0.62     0.62      0.66
# ...

# %%
print(train_df_EC1.var())
# Out:
# EState_VSA1          982.04
# EState_VSA2          183.63
# HallKierAlpha          0.86
# MaxAbsEStateIndex      2.43
# MinEStateIndex         4.26
# PEOE_VSA10           192.74
# PEOE_VSA14          1153.01
# PEOE_VSA6            360.70
# PEOE_VSA7            392.28
# SMR_VSA5            1074.40
# fr_COO                 0.44
# fr_COO2                0.44
# EC1                    0.22
# dtype: float64

# %%
train_df_EC1.drop(["Chi4n","PEOE_VSA8","SMR_VSA10"],axis=1,inplace=True)
correlated3 = train_df_EC1.drop(["EC1"],axis=1)
correlated3.corr()

# %%
train_df_EC1.drop(["HallKierAlpha","fr_COO"],axis=1,inplace=True)
correlated2 = train_df_EC1.drop(["EC1"],axis=1)
correlated2.corr()
# Out:
#                    EState_VSA1  EState_VSA2  MaxAbsEStateIndex  \
# EState_VSA1               1.00         0.38               0.58
# EState_VSA2               0.38         1.00               0.45
# MaxAbsEStateIndex         0.58         0.45               1.00
# MinEStateIndex           -0.76        -0.32              -0.56
# PEOE_VSA10                0.73         0.41               0.48
# PEOE_VSA14                0.33         0.08               0.25
# PEOE_VSA6                 0.15         0.41               0.20
# PEOE_VSA7                -0.16         0.17               0.08
# SMR_VSA5                  0.58         0.45               0.50
# fr_COO2                  -0.10        -0.10              -0.02
#
#                    MinEStateIndex  PEOE_VSA10  PEOE_VSA14  PEOE_VSA6  \
# EState_VSA1                 -0.76        0.73        0.33       0.15
# EState_VSA2                 -0.32        0.41        0.08       0.41
# ...

# %% [markdown]
# After all the operations, we can observe no significant improvement. Let's use feature importance available withing Random Forest Classifier.

# %%
from sklearn.ensemble import RandomForestClassifier
import numpy as np

model = RandomForestClassifier(random_state=1, max_depth=10)

fimp = train_df_EC1.drop(["EC1"],axis=1)

model.fit(fimp,train_df_EC1.EC1)
features = fimp.columns
importances = model.feature_importances_
indices = np.argsort(importances)
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
train_df_EC1.drop(["fr_COO2","PEOE_VSA6","PEOE_VSA7","PEOE_VSA10","EState_VSA2"],axis=1,inplace=True)

# %%
train_df_EC1.drop(["SMR_VSA5","PEOE_VSA14"],axis=1,inplace=True)

# %%
train_df_EC1.drop(["MaxAbsEStateIndex"],axis=1,inplace=True)

# %%
train_df_EC1.head()
# Out:
#    EState_VSA1  MaxAbsEStateIndex  MinEStateIndex  EC1
# 0         0.00              11.92            0.17    1
# 1        45.14              10.93           -4.83    0
# 2        15.65              11.24           -5.07    1
# 3        95.64              11.17           -5.28    1
# 4        17.98               9.86           -1.68    1

# %%
X = train_df_EC1.drop(["EC1"],axis=1)
y = train_df_EC1["EC1"]

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.25,random_state =123)

clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
prediction = clf.fit(X_train, X_test, y_train, y_test)
print(prediction)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [00:25<00:00,  1.12it/s]
# [LightGBM] [Info] Number of positive: 7456, number of negative: 3653
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000112 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 11109, number of used features: 2
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.671168 -> initscore=0.713470
# [LightGBM] [Info] Start training from score 0.713470
# (                               Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# NearestCentroid                    0.66               0.62     0.62      0.66
# PassiveAggressiveClassifier        0.65               0.62     0.62      0.65
# LGBMClassifier                     0.70               0.61     0.61      0.67
# ...

# %% [markdown]
# After several actions done to improve the model's performance, no siginificant changes happened. Let's try using the whole dataset.
