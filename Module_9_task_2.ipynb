# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data=pd.read_csv("C:/Users/pfali/Downloads/HRDataset (2).csv",index_col=False)
data.head()
# Out:
#   Employee_Name Employee_First_Name       EmpID  MarriedID  MaritalStatusID  \
# 0         Brown                 Mia  1103024456        1.0              1.0
# 1     LaRotonda           William    1106026572        0.0              2.0
# 2        Steans            Tyrone    1302053333        0.0              0.0
# 3        Howard             Estelle  1211050782        1.0              1.0
# 4         Singh                Nan   1307059817        0.0              0.0
#
#    GenderID  EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  ...  \
# 0       0.0          1.0     1.0          3.0                     1.0  ...
# 1       1.0          1.0     1.0          3.0                     0.0  ...
# 2       1.0          1.0     1.0          3.0                     0.0  ...
# 3       0.0          1.0     1.0          3.0                     0.0  ...
# 4       0.0          1.0     1.0          3.0                     0.0  ...
#
# ...

# %%
data['PerformanceScoreNo']=1

# %%
pd.set_option('display.max_rows',None)
data.head(311)
# Out:
#                                          Employee_Name Employee_First_Name  \
# 0                                                Brown                 Mia
# 1                                            LaRotonda           William
# 2                                               Steans            Tyrone
# 3                                               Howard             Estelle
# 4                                                Singh                Nan
# 5                                                Smith           Leigh Ann
# 6                                              Bunbury             Jessica
# 7                                               Carter           Michelle
# 8                                             Dietrich             Jenna
# 9                                             Digitale              Alfred
# 10                                            Friedman               Gerry
# 11                                                Gill           Whitney
# ...

# %% [markdown]
# Mimo kilku prób nie mogłam ustawić poprawnego odczytania rzędów 41,42,137, więc je usunę.

# %%
data.drop(index=[41,42,137],inplace=True)
data.reset_index()
# Out:
#      index   Employee_Name Employee_First_Name        EmpID  MarriedID  \
# 0        0           Brown                 Mia   1103024456        1.0
# 1        1       LaRotonda           William     1106026572        0.0
# 2        2          Steans            Tyrone     1302053333        0.0
# 3        3          Howard             Estelle   1211050782        1.0
# 4        4           Singh                Nan    1307059817        0.0
# 5        5           Smith           Leigh Ann    711007713        1.0
# 6        6         Bunbury             Jessica   1504073368        1.0
# 7        7          Carter           Michelle    1403065721        0.0
# 8        8        Dietrich             Jenna     1408069481        0.0
# 9        9        Digitale              Alfred  1306059/197        1.0
# 10      10        Friedman               Gerry   1204032843        0.0
# 11      11            Gill           Whitney     1302053046        0.0
# ...

# %%
data
# Out:
#       Employee_Name Employee_First_Name        EmpID  MarriedID  \
# 0             Brown                 Mia   1103024456        1.0
# 1         LaRotonda           William     1106026572        0.0
# 2            Steans            Tyrone     1302053333        0.0
# 3            Howard             Estelle   1211050782        1.0
# 4             Singh                Nan    1307059817        0.0
# 5             Smith           Leigh Ann    711007713        1.0
# 6           Bunbury             Jessica   1504073368        1.0
# 7            Carter           Michelle    1403065721        0.0
# 8          Dietrich             Jenna     1408069481        0.0
# 9          Digitale              Alfred  1306059/197        1.0
# 10         Friedman               Gerry   1204032843        0.0
# 11             Gill           Whitney     1302053046        0.0
# 12         Gonzales             Ricardo   1411071481        1.0
# 13        Guilianno                Mike   1001167253        0.0
# ...

# %%
#data.drop(columns=['index'],inplace=True)

# %%
data.isnull().sum()
# Out:
# Employee_Name                   0
# Employee_First_Name             0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# PayRate                         0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# TermReason                      1
# EmploymentStatus                0
# Department                      0
# ...

# %%
data[data['ManagerID'].isna()]
# Out:
#     Employee_Name Employee_First_Name       EmpID  MarriedID  MaritalStatusID  \
# 210        Becker               Scott  1110029777        0.0              0.0
# 211         Chang          Donovan  E  1111030129        0.0              0.0
# 220        Rivera             Haley    1405067642        1.0              1.0
# 221      Sewkumar                Nori   807010161        0.0              0.0
# 275      Buccheri            Joseph    1101023457        0.0              0.0
# 276       Fancett              Nicole  1402065085        0.0              0.0
# 277        Hutter             Rosalie  1103024924        0.0              3.0
# 278    Manchester               Robyn  1110029623        1.0              1.0
#
#      GenderID  EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  ...  \
# 210       1.0          3.0     5.0          3.0                     0.0  ...
# 211       1.0          1.0     5.0          3.0                     0.0  ...
# ...

# %% [markdown]
# Brakuje wartości dla Webstera Butlera, a jego ID to 39.

# %%
data['ManagerID'].fillna(39)
# Out:
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
# 5       1.0
# 6      17.0
# 7      17.0
# 8      17.0
# 9      17.0
# 10     17.0
# 11     17.0
# 12     17.0
# 13     17.0
# 14     17.0
# 15     17.0
# 16     17.0
# 17     17.0
# 18     17.0
# 19     17.0
# 20     21.0
# 21     21.0
# 22     21.0
# 23     21.0
# 24     21.0
# 25     21.0
# 26     21.0
# 27     21.0
# 28     21.0
# 29     21.0
# 30     21.0
# 31     21.0
# 32     21.0
# 33     13.0
# 34     13.0
# 35     13.0
# 36     13.0
# 37      5.0
# 38      2.0
# 39     13.0
# 40      4.0
# 43      4.0
# 44      4.0
# 45      4.0
# 46      4.0
# 47      4.0
# 48      4.0
# 49      4.0
# 50      4.0
# 51      4.0
# 52      4.0
# 53      2.0
# 54      2.0
# 55      5.0
# 56      5.0
# 57      5.0
# 58      5.0
# 59      5.0
# 60      6.0
# 61      6.0
# 62      6.0
# 63      6.0
# 64      7.0
# 65      7.0
# 66      7.0
# 67      7.0
# 68      7.0
# 69      7.0
# 70      7.0
# 71      7.0
# 72      7.0
# ...

# %%
data.isnull().sum()
# Out:
# Employee_Name                   0
# Employee_First_Name             0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# PayRate                         0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# TermReason                      1
# EmploymentStatus                0
# Department                      0
# ...

# %%
grouped=data[['PerformanceScore','ManagerID','PerformanceScoreNo']].groupby(['ManagerID','PerformanceScore']).sum().reset_index()
grouped
# Out:
#     ManagerID   PerformanceScore  PerformanceScoreNo
# 0         1.0        Fully Meets                   6
# 1         2.0            Exceeds                   4
# 2         2.0        Fully Meets                  13
# 3         2.0  Needs Improvement                   2
# 4         3.0        Fully Meets                   1
# 5         4.0            Exceeds                   2
# 6         4.0        Fully Meets                  13
# 7         5.0            Exceeds                   2
# 8         5.0        Fully Meets                   4
# 9         5.0  Needs Improvement                   1
# 10        6.0            Exceeds                   1
# 11        6.0        Fully Meets                   3
# 12        7.0        Fully Meets                  13
# 13        7.0                PIP                   1
# 14        9.0        Fully Meets                   2
# 15       10.0            Exceeds                   2
# 16       10.0        Fully Meets                   6
# ...

# %%
grouped.dtypes
grouped['ManagerID']=grouped['ManagerID'].astype('int')
grouped
# Out:
#     ManagerID   PerformanceScore  PerformanceScoreNo
# 0           1        Fully Meets                   6
# 1           2            Exceeds                   4
# 2           2        Fully Meets                  13
# 3           2  Needs Improvement                   2
# 4           3        Fully Meets                   1
# 5           4            Exceeds                   2
# 6           4        Fully Meets                  13
# 7           5            Exceeds                   2
# 8           5        Fully Meets                   4
# 9           5  Needs Improvement                   1
# 10          6            Exceeds                   1
# 11          6        Fully Meets                   3
# 12          7        Fully Meets                  13
# 13          7                PIP                   1
# 14          9        Fully Meets                   2
# 15         10            Exceeds                   2
# 16         10        Fully Meets                   6
# ...

# %%
plt.figure(figsize=(20,8))
plt.title('Ocena pracowników przez managerów')
sns.barplot(x=grouped['ManagerID'],y=grouped['PerformanceScoreNo'],hue=grouped['PerformanceScore'])
plt.ylabel("Liczba ocen")
plt.xlabel("ID managera")
plt.legend(loc='upper left')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data['DateofHire']=pd.to_datetime(data['DateofHire'])
data['DateofTermination']=pd.to_datetime(data['DateofTermination'])
data['current_date']="2023-09-07"
data['current_date']=pd.to_datetime(data['current_date'])
# Out:
# C:\Users\pfali\AppData\Local\Temp\ipykernel_71912\2262768609.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['DateofTermination']=pd.to_datetime(data['DateofTermination'])

# %%
data.dtypes
# Out:
# Employee_Name                         object
# Employee_First_Name                   object
# EmpID                                 object
# MarriedID                            float64
# MaritalStatusID                      float64
# GenderID                             float64
# EmpStatusID                          float64
# DeptID                               float64
# PerfScoreID                          float64
# FromDiversityJobFairID               float64
# PayRate                              float64
# Termd                                float64
# PositionID                           float64
# Position                              object
# State                                 object
# Zip                                   object
# DOB                                   object
# Sex                                   object
# MaritalDesc                           object
# CitizenDesc                           object
# HispanicLatino                        object
# ...

# %%
data['Seniority']=data['current_date']-data['DateofHire']
pd.set_option('display.max_rows',None)
data['Seniority']
# Out:
# 0     5428 days
# 1     3531 days
# 2     3265 days
# 3     3125 days
# 4     3051 days
# 5     4364 days
# 6     4406 days
# 7     3307 days
# 8     4217 days
# 9     3307 days
# 10    4567 days
# 11    3349 days
# 12    3405 days
# 13    4567 days
# 14    4147 days
# 15    3265 days
# 16    3167 days
# 17    4728 days
# 18    4447 days
# 19    4203 days
# 20    3265 days
# 21    4623 days
# 22    4384 days
# 23    3125 days
# 24    3405 days
# 25    3671 days
# 26    4133 days
# 27    2619 days
# 28    3713 days
# 29    3629 days
# 30    4259 days
# 31    6450 days
# 32    3265 days
# 33    2531 days
# 34    2395 days
# 35    2331 days
# 36    2331 days
# 37    2557 days
# 38    4898 days
# 39    2434 days
# 40    3349 days
# 43    3083 days
# 44    3167 days
# 45    3223 days
# 46    3202 days
# 47    3223 days
# 48    3125 days
# 49    3083 days
# 50    3167 days
# 51    3167 days
# 52    3083 days
# 53    5358 days
# 54    3412 days
# 55    4528 days
# 56    3882 days
# ...

# %%
data['Seniority_days']=data['Seniority'].dt.days
data['Seniority_years']=data['Seniority_days']/365
data['Seniority_years']
# Out:
# 0      14.871233
# 1       9.673973
# 2       8.945205
# 3       8.561644
# 4       8.358904
# 5      11.956164
# 6      12.071233
# 7       9.060274
# 8      11.553425
# 9       9.060274
# 10     12.512329
# 11      9.175342
# 12      9.328767
# 13     12.512329
# 14     11.361644
# 15      8.945205
# 16      8.676712
# 17     12.953425
# 18     12.183562
# 19     11.515068
# 20      8.945205
# 21     12.665753
# 22     12.010959
# 23      8.561644
# 24      9.328767
# 25     10.057534
# 26     11.323288
# 27      7.175342
# 28     10.172603
# 29      9.942466
# 30     11.668493
# 31     17.671233
# 32      8.945205
# 33      6.934247
# 34      6.561644
# 35      6.386301
# 36      6.386301
# 37      7.005479
# 38     13.419178
# 39      6.668493
# 40      9.175342
# 43      8.446575
# 44      8.676712
# 45      8.830137
# 46      8.772603
# 47      8.830137
# 48      8.561644
# 49      8.446575
# 50      8.676712
# 51      8.676712
# 52      8.446575
# 53     14.679452
# ...

# %%
seniority=data[['Seniority_years','RecruitmentSource']].groupby(['RecruitmentSource']).mean().reset_index()
seniority
# Out:
#                          RecruitmentSource  Seniority_years
# 0                                Billboard        11.696575
# 1                            Careerbuilder        12.435616
# 2               Company Intranet - Partner         8.446575
# 3                       Diversity Job Fair        11.597260
# 4                        Employee Referral         9.495890
# 5                                Glassdoor        10.546681
# 6                                   Indeed         6.626027
# 7                      Information Session        10.486301
# 8                          Internet Search        10.557534
# 9                                 MBTA ads        10.872844
# 10                             Monster.com        11.042352
# 11                      Newspager/Magazine        10.461948
# 12                    On-campus Recruiting         9.460731
# 13                 On-line Web application        10.958904
# 14                                   Other        12.504110
# ...

# %%
plt.figure(figsize=(20,8))
plt.title('Staż pracy a źródło pozyskania pracownika')
g=sns.barplot(data=seniority,x='RecruitmentSource',y='Seniority_years',color='orange')
plt.ylabel("Średni staż pracownika w latach")
plt.xlabel("Źródło pozyskania pracownika")
g.set_xticklabels(g.get_xticklabels(),rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(15,10))
plt.title('Zadowolenie z pracy a stan cywilny pracownika')
p=sns.countplot(x=data['EmpSatisfaction'],hue=data['MaritalDesc'])
plt.xlabel("Ocena zadowolenia pracownika")
plt.ylabel("Liczba pracowników")
p.legend(['zamężna/żonaty','rozwiedziony','singiel','owdowiały','w separacji'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data['DOB']=pd.to_datetime(data['DOB'],format='mixed')
data['Age']=(data['current_date']-data['DOB'])
data['Age_days']=data['Age'].dt.days
data['Age_years']=data['Age_days']/365
data['Age_years'].astype('int64')
# Out:
# 0      35
# 1      39
# 2      37
# 3      38
# 4      35
# 5      36
# 6      59
# 7      60
# 8      36
# 9      35
# 10     54
# 11     52
# 12     68
# 13     54
# 14     34
# 15     47
# 16     41
# 17     34
# 18     32
# 19     34
# 20     48
# 21     34
# 22     60
# 23     33
# 24     49
# 25     43
# 26     53
# 27     39
# 28     34
# 29     33
# 30     35
# 31     55
# 32     58
# 33     43
# 34     40
# 35     35
# 36     34
# 37     51
# 38     44
# 39     50
# 40     37
# 43     39
# 44     36
# 45     35
# 46     39
# 47     39
# 48     41
# 49     37
# 50     35
# 51     53
# 52     44
# 53     40
# 54     57
# 55     43
# 56     50
# 57     59
# 58     36
# 59     53
# 60     38
# 61     55
# 62     34
# 63     50
# 64     35
# 65     33
# 66     35
# 67     42
# 68     36
# 69     44
# 70     42
# 71     35
# 72     54
# 73     69
# 74     54
# 75     53
# 76     40
# 77     49
# 78     42
# 79     51
# 80     46
# 81     41
# 82     42
# 83     46
# 84     47
# ...

# %%
df=data.loc[data["DateofTermination"].isna(),"Age_years"]
df_age=pd.DataFrame(df)
df_age['Occurrences']=1
df_age['Age_years']=np.floor(pd.to_numeric(df_age['Age_years'],errors='coerce')).astype("Int64")
df_age.dtypes
# Out:
# Age_years      Int64
# Occurrences    int64
# dtype: object

# %%
plt.figure(figsize=(20,12))
plt.title('Struktura wiekowa aktualnie zatrudnionych pracowników')
sns.countplot(data=df_age,x='Age_years',color='lightskyblue')
plt.xlabel("Wiek pracowników w latach")
plt.ylabel("Liczba pracowników")
# Out:
# Text(0, 0.5, 'Liczba pracowników')

# %%
data['Occurrences']=df_age['Occurrences']

# %%
data['Age_years']=np.floor(pd.to_numeric(data['Age_years'],errors='coerce')).astype("Int64")

# %%
group=data[['Age_years','SpecialProjectsCount']].groupby('Age_years').sum().reset_index()
group
# Out:
#     Age_years  SpecialProjectsCount
# 0          31                   0.0
# 1          32                   0.0
# 2          33                   7.0
# 3          34                  10.0
# 4          35                  48.0
# 5          36                  41.0
# 6          37                  34.0
# 7          38                  10.0
# 8          39                  22.0
# 9          40                  21.0
# 10         41                   6.0
# 11         42                  18.0
# 12         43                  11.0
# 13         44                  31.0
# 14         45                   8.0
# 15         46                   0.0
# 16         47                   0.0
# 17         48                   6.0
# 18         49                   0.0
# 19         50                  24.0
# 20         51                   7.0
# 21         52                   0.0
# 22         53                  18.0
# 23         54                   7.0
# 24         55                   5.0
# ...

# %%
plt.figure(figsize=(20,12))
plt.title('Wiek pracowników a zaangażowanie w projektach specjalnych')
sns.barplot(data=group,x='Age_years',y='SpecialProjectsCount')
plt.xlabel("Wiek pracowników w latach")
plt.ylabel("Liczba projektów specjalnych")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
